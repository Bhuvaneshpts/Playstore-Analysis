# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv("Salary_Data.csv")

# %%
print(df)
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
df.tail()
# Out:
#        Age  Gender    Education Level              Job Title  \
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 6699                 20.0  200000.0
# 6700                  3.0   50000.0
# 6701                  4.0   55000.0
# 6702                 14.0  140000.0
# 6703                  1.0   35000.0

# %%
df.shape
# Out:
# (6704, 6)

# %%
df.size
# Out:
# 40224

# %%
df.shape[0]*df.shape[1]
# Out:
# 40224

# %%
df.ndim
# Out:
# 2

# %%
df['Age'].ndim
# Out:
# 1

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6704, step=1)

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience',
#        'Salary'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Age                    float64
# Gender                  object
# Education Level         object
# Job Title               object
# Years of Experience    float64
# Salary                 float64
# dtype: object

# %%
df['Age'].dtypes
# Out:
# dtype('float64')

# %%
df['Age'].unique()
# Out:
# array([32., 28., 45., 36., 52., 29., 42., 31., 26., 38., 48., 35., 40.,
#        27., 44., 33., 39., 25., 51., 34., 47., 30., 41., 37., 24., 43.,
#        50., 46., 49., 23., 53., nan, 61., 57., 62., 55., 56., 54., 60.,
#        58., 22., 21.])

# %%
df.nunique()
# Out:
# Age                     41
# Gender                   3
# Education Level          7
# Job Title              193
# Years of Experience     37
# Salary                 444
# dtype: int64

# %%
df.count()
# Out:
# Age                    6702
# Gender                 6702
# Education Level        6701
# Job Title              6702
# Years of Experience    6701
# Salary                 6699
# dtype: int64

# %%
df.isnull()
# Out:
#         Age  Gender  Education Level  Job Title  Years of Experience  Salary
# 0     False   False            False      False                False   False
# 1     False   False            False      False                False   False
# 2     False   False            False      False                False   False
# 3     False   False            False      False                False   False
# 4     False   False            False      False                False   False
# ...     ...     ...              ...        ...                  ...     ...
# 6699  False   False            False      False                False   False
# 6700  False   False            False      False                False   False
# 6701  False   False            False      False                False   False
# 6702  False   False            False      False                False   False
# 6703  False   False            False      False                False   False
#
# [6704 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Age                    2
# Gender                 2
# Education Level        3
# Job Title              2
# Years of Experience    3
# Salary                 5
# dtype: int64

# %%
df.notnull()
# Out:
#        Age  Gender  Education Level  Job Title  Years of Experience  Salary
# 0     True    True             True       True                 True    True
# 1     True    True             True       True                 True    True
# 2     True    True             True       True                 True    True
# 3     True    True             True       True                 True    True
# 4     True    True             True       True                 True    True
# ...    ...     ...              ...        ...                  ...     ...
# 6699  True    True             True       True                 True    True
# 6700  True    True             True       True                 True    True
# 6701  True    True             True       True                 True    True
# 6702  True    True             True       True                 True    True
# 6703  True    True             True       True                 True    True
#
# [6704 rows x 6 columns]

# %%
df.notnull().sum()
# Out:
# Age                    6702
# Gender                 6702
# Education Level        6701
# Job Title              6702
# Years of Experience    6701
# Salary                 6699
# dtype: int64

# %%
df['Age'].value_counts()
# Out:
# 27.0    517
# 30.0    449
# 29.0    444
# 28.0    429
# 33.0    398
# 26.0    394
# 31.0    365
# 32.0    351
# 34.0    309
# 25.0    284
# 36.0    282
# 24.0    240
# 35.0    200
# 42.0    176
# 43.0    158
# 39.0    158
# 37.0    156
# 38.0    149
# 45.0    144
# 41.0    129
# 44.0    126
# 23.0    104
# 46.0    102
# 48.0     98
# 40.0     92
# 49.0     91
# 50.0     88
# 54.0     68
# 47.0     47
# 51.0     30
# 52.0     29
# 21.0     18
# 55.0     16
# 22.0     15
# 56.0     11
# 57.0      9
# 53.0      7
# 58.0      7
# 62.0      5
# 60.0      5
# 61.0      2
# Name: Age, dtype: int64

# %%
df.info
# Out:
# <bound method DataFrame.info of        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# ...

# %%
df.describe()
# Out:
#                Age  Years of Experience         Salary
# count  6702.000000          6701.000000    6699.000000
# mean     33.620859             8.094687  115326.964771
# std       7.614633             6.059003   52786.183911
# min      21.000000             0.000000     350.000000
# 25%      28.000000             3.000000   70000.000000
# 50%      32.000000             7.000000  115000.000000
# 75%      38.000000            12.000000  160000.000000
# max      62.000000            34.000000  250000.000000

# %%
df.describe(include=['object'])
# Out:
#        Gender    Education Level          Job Title
# count    6702               6701               6702
# unique      3                  7                193
# top      Male  Bachelor's Degree  Software Engineer
# freq     3674               2267                518

# %%
df[df['Age']>30]['Age'].count()
# Out:
# 3808

# %%
df.dropna()
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
A=df['Age']
B=df['Years of Experience']
plt.plot(A,B)

# %%
plt.plot(A,B,color='green',linewidth=1.2,linestyle='--')

# %%
C=df['Salary']
plt.plot(A,C,color='red',linewidth=1,linestyle='dotted')

# %%
plt.plot(A,B)
plt.plot(A,C)
plt.title('Age vs Salary and Years of Experience')
plt.xlabel('Age')
plt.legend([' Salary ',' Years of Experience'])

# %%
plt.plot(A,B)
plt.title('Age vs Years of Experience')
plt.xlabel('Age')
plt.ylabel('Years of Experience')
plt.show()

plt.plot(A,C,color='orange')
plt.title('Age vs Salary')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()

# %%
plt.bar(A,B)
plt.show()

# %%
plt.hist(A)
plt.show()

# %%
plt.boxplot(B)
plt.show()

# %%
plt.scatter(A,B)
plt.show()

# %%
fig=plt.figure()
plt.scatter(A,B)
fig=plt.savefig('scatterplot.png')

# %%
sns.countplot(x='Years of Experience',data=df)
# Out:
# <AxesSubplot:xlabel='Years of Experience', ylabel='count'>

# %%
res=sns.kdeplot(df['Age'],df['Salary'],data=df,color='blue',shade=True)
plt.show()
# Out:
# C:\Users\Admin\anaconda3\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.displot(x='Age',kde=True,bins=10,data=df)

# %%
sns.jointplot(x='Age',y='Salary',data=df,kind='reg')

# %%
data=df

# %%
sns.catplot(data=df,x='Age',y='Salary',kind='strip',height=5,aspect=5.3)

# %%
res = sns.barplot(df['Age'],df['Years of Experience'])
plt.show()
# Out:
# C:\Users\Admin\anaconda3\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.heatmap(df.corr(), cbar=True, linewidths = 0.5)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x='Age',y='Years of Experience',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Years of Experience'>

# %%
sns.pairplot(df)

# %%
sns.lmplot(x='Age',y='Years of Experience',data=df)

# %%
sns.boxplot(x='Salary',y='Years of Experience',data=df)
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='Years of Experience'>

# %%
sns.countplot(x='Age',data=df,palette="Set1")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
sns.countplot(y='Age',data=df,palette='rocket')
# Out:
# <AxesSubplot:xlabel='count', ylabel='Age'>

# %%
sns.scatterplot(x='Salary',y='Years of Experience',data=df,hue='Education Level')
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='Years of Experience'>

# %%
sns.scatterplot(x='Salary',y='Years of Experience',data=df,hue='Gender')
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='Years of Experience'>

# %% [raw]
# sns.residplot(data=df, x="Age",y="Years of Experience")

# %%
sns.residplot(data=df, x="Age",y="Years of Experience")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Years of Experience'>

# %%
df.mean()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1088\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# Age                        33.620859
# Years of Experience         8.094687
# Salary                 115326.964771
# dtype: float64

# %%
df.median()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1088\530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# Age                        32.0
# Years of Experience         7.0
# Salary                 115000.0
# dtype: float64

# %%
df.max()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1088\1151452817.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.max()
# Age                        62.0
# Years of Experience        34.0
# Salary                 250000.0
# dtype: float64

# %%
df.min()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1088\3962516015.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.min()
# Age                     21.0
# Years of Experience      0.0
# Salary                 350.0
# dtype: float64

# %%
df.corr()
# Out:
#                           Age  Years of Experience    Salary
# Age                  1.000000             0.937655  0.728053
# Years of Experience  0.937655             1.000000  0.808969
# Salary               0.728053             0.808969  1.000000

# %%
plt.pie('Education Level')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1088\3443155501.py in <module>
# ----> 1 plt.pie('Education Level')
#       2 plt.show()
#
# ~\anaconda3\anaconda\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2754         textprops=None, center=(0, 0), frame=False,
#    2755         rotatelabels=False, *, normalize=True, data=None):
# -> 2756     return gca().pie(
#    2757         x, explode=explode, labels=labels, colors=colors,
#    2758         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#
# ~\anaconda3\anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
# ...
